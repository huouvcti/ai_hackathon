# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: 대상 경로가('yolov5') 이미 있고 빈 디렉터리가 아닙니다.

# %%
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# /home/uit-na/Desktop/yolov5/scratch/yolov5
# ...

# %%
# %cat dataset/data.yaml
# Out:
# cat: dataset/data.yaml: 그런 파일이나 디렉터리가 없습니다

# %%
# %cd Desktop/yolov5/scratch
# Out:
# /home/uit-na/Desktop/yolov5/scratch

# %%
from glob import glob

img_list = glob('./dataset/export/train/images/*.jpg')
print(len(img_list))
# Out:
# 82

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)

print(len(train_img_list), len(val_img_list))
# Out:
# 65 17

# %%
with open('train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')
    
with open('val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
import yaml

with open('./dataset/data.yaml', 'r') as f:
    data = yaml.load(f, Loader=yaml.FullLoader)

print(data)

data['train'] = '../train.txt'
data['val'] = '../val.txt'

with open('./dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'nc': 1, 'names': ['scratches']}
# {'train': '../train.txt', 'val': '../val.txt', 'nc': 1, 'names': ['scratches']}

# %%
# %cd yolov5
# Out:
# /home/uit-na/Desktop/yolov5/scratch/yolov5

# %%
# !python train.py --img 416 --batch 16 --epochs 1000 --data ../dataset/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name scratch_results_sss
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=../dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=scratch_results_sss, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.9.13 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11017MiB)
#
# ...
